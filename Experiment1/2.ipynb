# %%
import pandas as pd
import numpy as np
import re
import enchant
import string
from collections import defaultdict

# %%
import os 
# os.environ["JAVA_HOME"] = "C:\\Program Files\\Microsoft\\jdk-11.0.12.7-hotspot\\bin"

# %%
english_dict = enchant.Dict('en_IN')

# %%
# if not pt.started():
#     pt.init()
# Out:
# PyTerrier 0.9.2 has loaded Terrier 5.7 (built by craigm on 2022-11-10 18:30) and terrier-helper 0.0.7

# %%
corpus_path = 'E:/Pycharm/IR/Experiment1/Mails'
no_documents = 100

# %%
words = set()
ordered_words = [[] for i in range(no_documents)]

# %%
icon_pattern = (r'[\U0001F600-\U0001F64F\U0001F300-\U0001F5FF\U0001F680-'
                r'\U0001F6FF\U0001F700-\U0001F77F\U0001F780-\U0001F7FF'
                r'\U0001F800-\U0001F8FF\U0001F900-\U0001F9FF\U0001FA00-'
                r'\U0001FA6F\U0001FA70-\U0001FAFF\U0001FB00-\U0001FBFF'
                r'\U0001FC00-\U0001FCFF\U0001FD00-\U0001FDFF\U0001FE00-'
                r'\U0001FEFF\U0001FF00-\U0001FFFF]+')
translation_table = str.maketrans(string.punctuation, ' ' * len(string.punctuation))

# %%
# pattern = r'[&#\n*/.,!?(){}<>\[\]"\'=;,@\d]'
# symbols_to_remove = r'[!\"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~]'

# %%
for i in range(no_documents):
    with open(f'{corpus_path}/email_{i}.txt', 'r' ,encoding='utf-8') as file:
        text = file.read()
        text = text.translate(translation_table) # symbol removal
        text = re.sub(icon_pattern, '', text).split(' ') # icon removal
        for word in text:
            word = str(word).lower()
            word = re.sub(r'[\d]', '', word) # digit removal
            if word and english_dict.check(word): # valid english word checking
                if len(word) != 1:
                    ordered_words[i].append(word)
                    words.add(word)

# %%
number_of_unique_words = len(list(words))
number_of_unique_words
# Out:
# 2789

# %%
sorted_words = sorted(words)
bigram = pd.DataFrame(0, 
                      columns=list(sorted_words), 
                      index=list(sorted_words))

# %%
for docno in range(no_documents):
    for i in range(len(ordered_words[docno]) - 1):
        bigram.loc[ordered_words[docno][i + 1], ordered_words[docno][i]] += 1

# %%
word_sequences = defaultdict(int)
for docno in range(no_documents):
    for i in range(len(ordered_words[docno]) - 2):
        seq = tuple(ordered_words[docno][i: i + 3])
        word_sequences[seq] += 1

# %%
word_sequences
# Out:
# defaultdict(int,
#             {('subject', 'event', 'wrap'): 2,
#              ('event', 'wrap', 'up'): 4,
#              ('wrap', 'up', 'institute'): 2,
#              ('up', 'institute', 'of'): 2,
#              ('institute', 'of', 'information'): 16,
#              ('of', 'information', 'technology'): 16,
#              ('information', 'technology', 'international'): 9,
#              ('technology', 'international', 'campus'): 9,
#              ('international', 'campus', 'introduction'): 2,
#              ('campus', 'introduction', 'to'): 2,
#              ('introduction', 'to', 'google'): 2,
#              ('to', 'google', 'student'): 2,
#              ('google', 'student', 'clubs'): 2,
#              ('student', 'clubs', 'congratulations'): 1,
#              ('clubs', 'congratulations', 'your'): 1,
#              ('congratulations', 'your', 'latest'): 2,
#              ('your', 'latest', 'institute'): 2,
#              ('latest', 'institute', 'of'): 2,
#              ('international', 'campus', 'event'): 2,
#              ('campus', 'event', 'is'): 1,
#              ('event', 'is', 'complete'): 2,
#              ('is', 'complete', 'make'): 2,
#              ('complete', 'make', 'sure'): 2,
#              ('make', 'sure', 'you'): 2,
#              ('sure', 'you', 'wrap'): 2,
#              ('you', 'wrap', 'up'): 2,
#              ('wrap', 'up', 'the'): 2,
#              ('up', 'the', 'event'): 2,
#              ('the', 'event', 'with'): 2,
#              ('event', 'with', 'the'): 2,
#              ('with', 'the', 'following'): 2,
#              ('the', 'following', 'actions'): 2,
#              ('following', 'actions', 'complete'): 2,
#              ('actions', 'complete', 'your'): 2,
#              ('complete', 'your', 'post'): 2,
#              ('your', 'post', 'event'): 2,
#              ('post', 'event', 'reporting'): 2,
#              ('event', 'reporting', 'form'): 2,
#              ('reporting', 'form', 'ct'): 2,
#              ('form', 'ct', 'net'): 2,
#              ('ct', 'net', 'ls'): 11,
#              ('net', 'ls', 'click'): 11,
#              ('ls', 'click', 'if'): 2,
#              ('click', 'if', 'you'): 2,
#              ('if', 'you', 'have'): 6,
#              ('you', 'have', 'video'): 2,
#              ('have', 'video', 'or'): 2,
#              ('video', 'or', 'photos'): 2,
#              ('or', 'photos', 'to'): 2,
#              ('photos', 'to', 'upload'): 2,
#              ('to', 'upload', 'include'): 2,
#              ('upload', 'include', 'them'): 2,
#              ('include', 'them', 'in'): 2,
#              ('them', 'in', 'the'): 2,
#              ('in', 'the', 'event'): 3,
#              ('the', 'event', 'wrap'): 2,
#              ('wrap', 'up', 'tab'): 2,
#              ('up', 'tab', 'make'): 2,
#              ('tab', 'make', 'sure'): 2,
#              ('make', 'sure', 'next'): 2,
#              ('sure', 'next', 'month'): 2,
#              ('next', 'month', 'event'): 2,
#              ('month', 'event', 'is'): 2,
#              ('event', 'is', 'online'): 2,
#              ('is', 'online', 'to'): 2,
#              ('online', 'to', 'keep'): 2,
#              ('to', 'keep', 'the'): 2,
#              ('keep', 'the', 'momentum'): 2,
#              ('the', 'momentum', 'going'): 2,
#              ('momentum', 'going', 'start'): 2,
#              ('going', 'start', 'creating'): 2,
#              ('start', 'creating', 'it'): 2,
#              ('creating', 'it', 'now'): 2,
#              ('it', 'now', 'look'): 2,
#              ('now', 'look', 'in'): 2,
#              ('look', 'in', 'the'): 2,
#              ('in', 'the', 'mirror'): 2,
#              ('the', 'mirror', 'and'): 2,
#              ('mirror', 'and', 'know'): 2,
#              ('and', 'know', 'you'): 2,
#              ('know', 'you', 're'): 2,
#              ('you', 're', 'awesome'): 2,
#              ('re', 'awesome', 'thanks'): 2,
#              ('awesome', 'thanks', 'for'): 2,
#              ('thanks', 'for', 'your'): 2,
#              ('for', 'your', 'amazing'): 2,
#              ('your', 'amazing', 'work'): 2,
#              ('amazing', 'work', 'in'): 2,
#              ('work', 'in', 'browser'): 2,
#              ('in', 'browser', 'ct'): 4,
#              ('browser', 'ct', 'net'): 4,
#              ('ls', 'click', 'here'): 2,
#              ('click', 'here', 'to'): 2,
#              ('here', 'to', 'unsubscribe'): 3,
#              ('to', 'unsubscribe', 'ct'): 3,
#              ('unsubscribe', 'ct', 'net'): 3,
#              ('subject', 'virtual', 'lab'): 1,
#              ('virtual', 'lab', 'creation'): 1,
#              ('lab', 'creation', 'under'): 1,
#              ('creation', 'under', 'dear'): 1,
#              ('under', 'dear', 'students'): 1,
#              ('dear', 'students', 'of'): 2,
#              ('students', 'of', 'institutes'): 1,
#              ('of', 'institutes', 'like'): 1,
#              ('institutes', 'like', 'and'): 1,
#              ('like', 'and', 'are'): 1,
#              ('and', 'are', 'contributing'): 1,
#              ('are', 'contributing', 'to'): 1,
#              ('contributing', 'to', 'the'): 1,
#              ('to', 'the', 'creation'): 1,
#              ('the', 'creation', 'of'): 1,
#              ('creation', 'of', 'lab'): 1,
#              ('of', 'lab', 'if'): 1,
#              ('lab', 'if', 'you'): 1,
#              ('you', 'have', 'developed'): 1,
#              ('have', 'developed', 'something'): 1,
#              ('developed', 'something', 'in'): 1,
#              ('something', 'in', 'any'): 1,
#              ('in', 'any', 'subject'): 1,
#              ('any', 'subject', 'can'): 1,
#              ('subject', 'can', 'come'): 1,
#              ('can', 'come', 'with'): 1,
#              ('come', 'with', 'we'): 1,
#              ('with', 'we', 'as'): 1,
#              ('we', 'as', 'team'): 1,
#              ('as', 'team', 'of'): 1,
#              ('team', 'of', 'can'): 1,
#              ('of', 'can', 'also'): 1,
#              ('can', 'also', 'make'): 1,
#              ('also', 'make', 'such'): 1,
#              ('make', 'such', 'types'): 1,
#              ('such', 'types', 'of'): 1,
#              ('types', 'of', 'innovative'): 1,
#              ('of', 'innovative', 'for'): 1,
#              ('innovative', 'for', 'your'): 1,
#              ('for', 'your', 'reference'): 3,
#              ('your', 'reference', 'just'): 1,
#              ('reference', 'just', 'click'): 1,
#              ('just', 'click', 'the'): 1,
#              ('click', 'the', 'link'): 1,
#              ('the', 'link', 'below'): 1,
#              ('link', 'below', 'co'): 1,
#              ('below', 'co', 'in'): 1,
#              ('co', 'in', 'can'): 1,
#              ('in', 'can', 'also'): 1,
#              ('can', 'also', 'discuss'): 1,
#              ('also', 'discuss', 'with'): 1,
#              ('discuss', 'with', 'the'): 1,
#              ('with', 'the', 'team'): 1,
#              ('the', 'team', 'of'): 1,
#              ('team', 'of', 'for'): 1,
#              ('of', 'for', 'deployment'): 1,
#              ('for', 'deployment', 'of'): 1,
#              ('deployment', 'of', 'such'): 1,
#              ('of', 'such', 'on'): 1,
#              ('such', 'on', 'our'): 1,
#              ('on', 'our', 'institute'): 1,
#              ('our', 'institute', 'website'): 1,
#              ('institute', 'website', 'dr'): 1,
#              ('website', 'dr', 'assistant'): 1,
#              ('dr', 'assistant', 'professor'): 1,
#              ('assistant', 'professor', 'pic'): 1,
#              ('professor', 'pic', 'academic'): 1,
#              ('pic', 'academic', 'institute'): 1,
#              ('academic', 'institute', 'of'): 1,
#              ('subject', 'hello', 'students'): 1,
#              ('hello', 'students', 'we'): 1,
#              ('students', 'we', 'would'): 1,
#              ('we', 'would', 'like'): 1,
#              ('would', 'like', 'to'): 5,
#              ('like', 'to', 'congratulate'): 1,
#              ('to', 'congratulate', 'you'): 1,
#              ('congratulate', 'you', 'on'): 1,
#              ('you', 'on', 'getting'): 1,
#              ('on', 'getting', 'shortlisted'): 1,
#              ('getting', 'shortlisted', 'for'): 1,
#              ('shortlisted', 'for', 'the'): 2,
#              ('for', 'the', 'program'): 1,
#              ('the', 'program', 'in'): 2,
#              ('program', 'in', 'collaboration'): 1,
#              ('in', 'collaboration', 'with'): 1,
#              ('collaboration', 'with', 'is'): 1,
#              ('with', 'is', 'organizing'): 1,
#              ('is', 'organizing', 'month'): 1,
#              ('organizing', 'month', 'training'): 1,
#              ('month', 'training', 'internship'): 2,
#              ('training', 'internship', 'program'): 1,
#              ('internship', 'program', 'designed'): 1,
#              ('program', 'designed', 'by'): 1,
#              ('designed', 'by', 'we'): 1,
#              ('by', 'we', 'are'): 1,
#              ('we', 'are', 'enrolling'): 1,
#              ('are', 'enrolling', 'limited'): 1,
#              ('enrolling', 'limited', 'students'): 1,
#              ('limited', 'students', 'in'): 1,
#              ('students', 'in', 'the'): 1,
#              ('in', 'the', 'program'): 1,
#              ('the', 'program', 'interested'): 1,
#              ('program', 'interested', 'students'): 1,
#              ('interested', 'students', 'fill'): 2,
#              ('students', 'fill', 'out'): 1,
#              ('fill', 'out', 'the'): 1,
#              ('out', 'the', 'form'): 1,
#              ('the', 'form', 'if'): 1,
#              ('form', 'if', 'you'): 2,
#              ('if', 'you', 'get'): 1,
#              ('you', 'get', 'shortlisted'): 1,
#              ('get', 'shortlisted', 'you'): 1,
#              ('shortlisted', 'you', 'will'): 2,
#              ('you', 'will', 'be'): 3,
#              ('will', 'be', 'call'): 1,
#              ('be', 'call', 'from'): 1,
#              ('call', 'from', 'our'): 2,
#              ('from', 'our', 'hr'): 2,
#              ('our', 'hr', 'team'): 2,
#              ('hr', 'team', 'students'): 1,
#              ('team', 'students', 'kindly'): 1,
#              ('students', 'kindly', 'go'): 1,
#              ('kindly', 'go', 'through'): 1,
#              ('go', 'through', 'all'): 1,
#              ('through', 'all', 'the'): 1,
#              ('all', 'the', 'information'): 1,
#              ('the', 'information', 'which'): 1,
#              ('information', 'which', 'is'): 1,
#              ('which', 'is', 'mentioned'): 1,
#              ('is', 'mentioned', 'in'): 1,
#              ('mentioned', 'in', 'the'): 1,
#              ('in', 'the', 'of'): 1,
#              ('the', 'of', 'the'): 3,
#              ('of', 'the', 'google'): 1,
#              ('the', 'google', 'form'): 3,
#              ('google', 'form', 'before'): 1,
#              ('form', 'before', 'filling'): 1,
#              ('before', 'filling', 'the'): 1,
#              ('filling', 'the', 'google'): 1,
#              ('google', 'form', 'google'): 1,
#              ('form', 'google', 'form'): 1,
#              ('google', 'form', 'forms'): 1,
#              ('form', 'forms', 'forms'): 1,
#              ('forms', 'forms', 'after'): 1,
#              ('forms', 'after', 'completion'): 1,
#              ('after', 'completion', 'of'): 1,
#              ('completion', 'of', 'the'): 1,
#              ('of', 'the', 'program'): 3,
#              ('the', 'program', 'the'): 1,
#              ('program', 'the', 'student'): 1,
#              ('the', 'student', 'shall'): 1,
#              ('student', 'shall', 'receive'): 1,
#              ('shall', 'receive', 'program'): 1,
#              ('receive', 'program', 'completion'): 1,
#              ('program', 'completion', 'certificate'): 1,
#              ('completion', 'certificate', 'issued'): 1,
#              ('certificate', 'issued', 'by'): 1,
#              ('issued', 'by', 'co'): 1,
#              ('by', 'co', 'branded'): 1,
#              ('co', 'branded', 'internship'): 1,
#              ('branded', 'internship', 'certificate'): 1,
#              ('internship', 'certificate', 'letter'): 1,
#              ('certificate', 'letter', 'of'): 1,
#              ('letter', 'of', 'recommendation'): 1,
#              ('of', 'recommendation', 'from'): 1,
#              ('recommendation', 'from', 'access'): 1,
#              ('from', 'access', 'to'): 1,
#              ('access', 'to', 'growing'): 1,
#              ('to', 'growing', 'community'): 1,
#              ('growing', 'community', 'find'): 1,
#              ('community', 'find', 'the'): 1,
#              ('find', 'the', 'below'): 1,
#              ('the', 'below', 'attachments'): 1,
#              ('below', 'attachments', 'for'): 1,
#              ('attachments', 'for', 'reference'): 1,
#              ('for', 'reference', 'program'): 1,
#              ('reference', 'program', 'provides'): 1,
#              ('program', 'provides', 'comprehensive'): 1,
#              ('provides', 'comprehensive', 'and'): 1,
#              ('comprehensive', 'and', 'immersive'): 1,
#              ('and', 'immersive', 'learning'): 1,
#              ('immersive', 'learning', 'by'): 1,
#              ('learning', 'by', 'industry'): 1,
#              ('by', 'industry', 'professionals'): 1,
#              ('industry', 'professionals', 'having'): 1,
#              ('professionals', 'having', 'years'): 1,
#              ('having', 'years', 'of'): 1,
#              ('years', 'of', 'work'): 1,
#              ('of', 'work', 'ex'): 1,
#              ('work', 'ex', 'with'): 1,
#              ('ex', 'with', 'over'): 1,
#              ('with', 'over', 'hours'): 1,
#              ('over', 'hours', 'of'): 1,
#              ('hours', 'of', 'content'): 1,
#              ('of', 'content', 'spread'): 1,
#              ('content', 'spread', 'across'): 1,
#              ('spread', 'across', 'modules'): 1,
#              ('across', 'modules', 'prerequisite'): 1,
#              ('modules', 'prerequisite', 'classes'): 1,
#              ('prerequisite', 'classes', 'students'): 1,
#              ('classes', 'students', 'have'): 1,
#              ('students', 'have', 'the'): 1,
#              ('have', 'the', 'foundational'): 1,
#              ('the', 'foundational', 'knowledge'): 1,
#              ('foundational', 'knowledge', 'required'): 1,
#              ('knowledge', 'required', 'to'): 1,
#              ('required', 'to', 'make'): 1,
#              ('to', 'make', 'them'): 1,
#              ('make', 'them', 'ready'): 1,
#              ('them', 'ready', 'internship'): 1,
#              ('ready', 'internship', 'provides'): 1,
#              ('internship', 'provides', 'practical'): 1,
#              ('provides', 'practical', 'experience'): 1,
#              ('practical', 'experience', 'with'): 1,
#              ('experience', 'with', 'live'): 1,
#              ('with', 'live', 'projects'): 1,
#              ('live', 'projects', 'alongside'): 1,
#              ('projects', 'alongside', 'the'): 1,
#              ('alongside', 'the', 'training'): 1,
#              ('the', 'training', 'program'): 1,
#              ('training', 'program', 'projects'): 1,
#              ('program', 'projects', 'challenge'): 1,
#              ('projects', 'challenge', 'to'): 1,
#              ('challenge', 'to', 'apply'): 1,
#              ('to', 'apply', 'learned'): 1,
#              ('apply', 'learned', 'skills'): 1,
#              ('learned', 'skills', 'in'): 1,
#              ('skills', 'in', 'real'): 1,
#              ('in', 'real', 'world'): 2,
#              ('real', 'world', 'situations'): 2,
#              ('world', 'situations', 'the'): 1,
#              ('situations', 'the', 'capstone'): 1,
#              ('the', 'capstone', 'integrated'): 1,
#              ('capstone', 'integrated', 'into'): 1,
#              ('integrated', 'into', 'the'): 1,
#              ('into', 'the', 'final'): 1,
#              ('the', 'final', 'week'): 1,
#              ('final', 'week', 'of'): 1,
#              ('week', 'of', 'the'): 2,
#              ('of', 'the', 'internship'): 1,
#              ('the', 'internship', 'requires'): 1,
#              ('internship', 'requires', 'to'): 1,
#              ('requires', 'to', 'apply'): 1,
#              ('to', 'apply', 'all'): 1,
#              ('apply', 'all', 'learned'): 1,
#              ('all', 'learned', 'skills'): 1,
#              ('learned', 'skills', 'and'): 1,
#              ('skills', 'and', 'knowledge'): 1,
#              ('and', 'knowledge', 'official'): 1,
#              ('knowledge', 'official', 'website'): 1,
#              ('official', 'website', 'com'): 1,
#              ('website', 'com', 'com'): 1,
#              ('com', 'com', 'profile'): 1,
#              ('com', 'profile', 'com'): 1,
#              ('profile', 'com', 'company'): 1,
#              ('com', 'company', 'com'): 1,
#              ('company', 'com', 'company'): 1,
#              ('com', 'company', 'account'): 1,
#              ('company', 'account', 'manager'): 1,
#              ('account', 'manager', 'com'): 1,
#              ('manager', 'com', 'com'): 1,
#              ('information', 'technology', 'core'): 1,
#              ('technology', 'core', 'members'): 1,
#              ('core', 'members', 'and'): 4,
#              ('members', 'and', 'domain'): 4,
#              ('and', 'domain', 'leads'): 3,
#              ('domain', 'leads', 'congratulations'): 1,
#              ('leads', 'congratulations', 'your'): 1,
#              ('information', 'technology', 'event'): 1,
#              ('technology', 'event', 'is'): 1,
#              ('subject', 'welcome', 'to'): 1,
#              ('welcome', 'to', 'institute'): 1,
#              ('to', 'institute', 'of'): 1,
#              ('international', 'campus', 'welcome'): 1,
#              ('campus', 'welcome', 'thanks'): 1,
#              ('welcome', 'thanks', 'for'): 1,
#              ('thanks', 'for', 'joining'): 1,
#              ('for', 'joining', 'institute'): 1,
#              ('joining', 'institute', 'of'): 1,
#              ('international', 'campus', 'stay'): 1,
#              ('campus', 'stay', 'tuned'): 1,
#              ('stay', 'tuned', 'for'): 1,
#              ('tuned', 'for', 'upcoming'): 1,
#              ('for', 'upcoming', 'events'): 1,
#              ('upcoming', 'events', 'in'): 1,
#              ('events', 'in', 'the'): 2,
#              ('in', 'the', 'meantime'): 1,
#              ('the', 'meantime', 'visit'): 1,
#              ('meantime', 'visit', 'the'): 1,
#              ('visit', 'the', 'community'): 1,
#              ('the', 'community', 'page'): 1,
#              ('community', 'page', 'to'): 1,
#              ('page', 'to', 'learn'): 1,
#              ('to', 'learn', 'more'): 2,
#              ('learn', 'more', 'about'): 2,
#              ('more', 'about', 'us'): 1,
#              ('about', 'us', 'and'): 1,
#              ('us', 'and', 'to'): 1,
#              ('and', 'to', 'contact'): 1,
#              ('to', 'contact', 'our'): 1,
#              ('contact', 'our', 'developer'): 1,
#              ('our', 'developer', 'student'): 2,
#              ('developer', 'student', 'club'): 5,
#              ('student', 'club', 'organizer'): 1,
#              ('club', 'organizer', 'with'): 1,
#              ('organizer', 'with', 'suggestions'): 1,
#              ('with', 'suggestions', 'or'): 1,
#              ('suggestions', 'or', 'feedback'): 1,
#              ('or', 'feedback', 'view'): 1,
#              ('feedback', 'view', 'group'): 1,
#              ('view', 'group', 'page'): 1,
#              ('group', 'page', 'are'): 1,
#              ('page', 'are', 'receiving'): 1,
#              ('are', 'receiving', 'this'): 4,
#              ('receiving', 'this', 'email'): 4,
#              ('this', 'email', 'because'): 4,
#              ('email', 'because', 'you'): 4,
#              ('because', 'you', 'have'): 2,
#              ('you', 'have', 'signed'): 2,
#              ('have', 'signed', 'up'): 2,
#              ('signed', 'up', 'as'): 2,
#              ('up', 'as', 'member'): 2,
#              ('as', 'member', 'of'): 2,
#              ('member', 'of', 'developer'): 2,
#              ('of', 'developer', 'student'): 2,
#              ('student', 'club', 'to'): 2,
#              ('club', 'to', 'change'): 2,
#              ('to', 'change', 'your'): 2,
#              ('change', 'your', 'email'): 2,
#              ('your', 'email', 'preferences'): 2,
#              ('email', 'preferences', 'visit'): 2,
#              ('preferences', 'visit', 'institute'): 2,
#              ('visit', 'institute', 'of'): 2,
#              ('international', 'campus', 'to'): 2,
#              ('campus', 'to', 'leave'): 2,
#              ('to', 'leave', 'the'): 2,
#              ('leave', 'the', 'group'): 2,
#              ('the', 'group', 'unsubscribe'): 2,
#              ('group', 'unsubscribe', 'below'): 2,
#              ('unsubscribe', 'below', 'in'): 2,
#              ('below', 'in', 'browser'): 2,
#              ('subject', 'no', 'include'): 1,
#              ('no', 'include', 'stdio'): 1,
#              ('include', 'stdio', 'include'): 1,
#              ('stdio', 'include', 'include'): 1,
#              ('include', 'include', 'include'): 2,
#              ('include', 'include', 'locale'): 1,
#              ('include', 'locale', 'include'): 1,
#              ('locale', 'include', 'types'): 1,
#              ('include', 'types', 'include'): 1,
#              ('types', 'include', 'wait'): 1,
#              ('include', 'wait', 'zombie'): 1,
#              ('wait', 'zombie', 'creation'): 1,
#              ('zombie', 'creation', 'zombie'): 1,
#              ('creation', 'zombie', 'creation'): 1,
#              ('zombie', 'creation', 'fork'): 1,
#              ('creation', 'fork', 'child'): 1,
#              ('fork', 'child', 'complete'): 1,
#              ('child', 'complete', 'exit'): 1,
#              ('complete', 'exit', 'else'): 1,
#              ('exit', 'else', 'parent'): 1,
#              ('else', 'parent', 'waiting'): 1,
#              ('parent', 'waiting', 'null'): 1,
#              ('waiting', 'null', 'child'): 1,
#              ('null', 'child', 'terminated'): 1,
#              ('child', 'terminated', 'main'): 1,
#              ('terminated', 'main', 'creation'): 1,
#              ('subject', 'fwd', 'reminder'): 2,
#              ('fwd', 'reminder', 'to'): 2,
#              ('reminder', 'to', 'disseminate'): 3,
#              ('to', 'disseminate', 'information'): 3,
#              ('disseminate', 'information', 'about'): 3,
#              ('information', 'about', 'stem'): 3,
#              ('about', 'stem', 'program'): 1,
#              ('stem', 'program', 'paid'): 1,
#              ('program', 'paid', 'internship'): 1,
#              ('paid', 'internship', 'and'): 3,
#              ('internship', 'and', 'mentorship'): 3,
#              ('and', 'mentorship', 'amongst'): 3,
#              ('mentorship', 'amongst', 'students'): 3,
#              ('amongst', 'students', 'with'): 3,
#              ('students', 'with', 'col'): 1,
#              ('with', 'col', 'forwarded'): 1,
#              ('col', 'forwarded', 'message'): 2,
#              ('forwarded', 'message', 'director'): 1,
#              ('message', 'director', 'director'): 1,
#              ('director', 'director', 'ac'): 4,
#              ('director', 'ac', 'in'): 58,
#              ('ac', 'in', 'jun'): 2,
#              ('in', 'jun', 'at'): 2,
#              ('jun', 'at', 'fwd'): 1,
#              ('at', 'fwd', 'reminder'): 1,
#              ('about', 'stem', 'fellowship'): 2,
#              ('stem', 'fellowship', 'paid'): 2,
#              ('fellowship', 'paid', 'internship'): 2,
#              ('students', 'with', 'registrar'): 1,
#              ('with', 'registrar', 'registrar'): 1,
#              ('registrar', 'registrar', 'ac'): 6,
#              ('registrar', 'ac', 'in'): 105,
#              ('ac', 'in', 'prof'): 3,
#              ('in', 'prof', 'director'): 2,
#              ('prof', 'director', 'forwarded'): 4,
#              ('director', 'forwarded', 'message'): 4,
#              ('forwarded', 'message', 'org'): 1,
#              ('message', 'org', 'jun'): 1,
#              ('org', 'jun', 'at'): 1,
#              ('jun', 'at', 'reminder'): 1,
#              ('at', 'reminder', 'to'): 1,
#              ('students', 'with', 'director'): 1,
#              ('with', 'director', 'ac'): 1,
#              ('in', 'prof', 'is'): 1,
#              ('prof', 'is', 'gentle'): 1,
#              ('is', 'gentle', 'reminder'): 2,
#              ('gentle', 'reminder', 'to'): 1,
#              ('reminder', 'to', 'my'): 1,
#              ('to', 'my', 'previous'): 1,
#              ('my', 'previous', 'email'): 1,
#              ('previous', 'email', 'quickly'): 1,
#              ('email', 'quickly', 'want'): 1,
#              ('quickly', 'want', 'to'): 1,
#              ('want', 'to', 'remind'): 1,
#              ('to', 'remind', 'that'): 1,
#              ('remind', 'that', 'stem'): 1,
#              ('that', 'stem', 'fellowships'): 1,
#              ('stem', 'fellowships', 'are'): 1,
#              ('fellowships', 'are', 'open'): 1,
#              ('are', 'open', 'until'): 1,
#              ('open', 'until', 'students'): 1,
#              ('until', 'students', 'can'): 1,
#              ('students', 'can', 'and'): 1,
#              ('can', 'and', 'know'): 1,
#              ('and', 'know', 'more'): 1,
#              ('know', 'more', 'about'): 1,
#              ('more', 'about', 'it'): 1,
#              ('about', 'it', 'at'): 1,
#              ('it', 'at', 'org'): 1,
#              ('at', 'org', 'fellowship'): 1,
#              ('org', 'fellowship', 'request'): 1,
#              ('fellowship', 'request', 'you'): 1,
#              ('request', 'you', 'to'): 3,
#              ('you', 'to', 'please'): 1,
#              ('to', 'please', 'this'): 1,
#              ('please', 'this', 'opportunity'): 1,
#              ('this', 'opportunity', 'with'): 1,
#              ('opportunity', 'with', 'your'): 1,
#              ('with', 'your', 'students'): 3,
#              ('your', 'students', 'with'): 2,
#              ('students', 'with', 'disabilities'): 1,
#              ('with', 'disabilities', 'if'): 1,
#              ('disabilities', 'if', 'not'): 1,
#              ('if', 'not', 'already'): 1,
#              ('subject', 'new', 'material'): 1,
#              ('new', 'material', 'deadlocks'): 1,
#              ('material', 'deadlocks', 'posted'): 1,
#              ('deadlocks', 'posted', 'new'): 1,
#              ('posted', 'new', 'material'): 1,
#              ('new', 'material', 'in'): 1,
#              ('material', 'in', 'cs'): 1,
#              ('in', 'cs', 'operating'): 2,
#              ('cs', 'operating', 'systems'): 2,
#              ('operating', 'systems', 'sem'): 2,
#              ('systems', 'sem', 'accounts'): 2,
#              ('sem', 'accounts', 'google'): 4,
#              ('accounts', 'google', 'com'): 53,
#              ('google', 'com', 'continue'): 53,
#              ('com', 'continue', 'classroom'): 53,
#              ('continue', 'classroom', 'google'): 53,
#              ('classroom', 'google', 'com'): 54,
#              ('google', 'com', 'email'): 38,
#              ('com', 'email', 'ac'): 38,
#              ('email', 'ac', 'in'): 53,
#              ('ac', 'in', 'material'): 1,
#              ('in', 'material', 'accounts'): 1,
#              ('material', 'accounts', 'google'): 1,
#              ('google', 'com', 'details'): 5,
#              ('com', 'details', 'email'): 5,
#              ('details', 'email', 'ac'): 5,
#              ('ac', 'in', 'mar'): 8,
#              ('in', 'mar', 'by'): 6,
#              ('mar', 'by', 'amphitheatre'): 4,
#              ('by', 'amphitheatre', 'parkway'): 8,
#              ('amphitheatre', 'parkway', 'mountain'): 16,
#              ('parkway', 'mountain', 'view'): 16,
#              ('mountain', 'view', 'ca'): 17,
#              ('view', 'ca', 'you'): 16,
#              ('ca', 'you', 'don'): 16,
#              ('you', 'don', 'want'): 17,
#              ('don', 'want', 'to'): 17,
#              ('want', 'to', 'receive'): 17,
#              ('to', 'receive', 'emails'): 16,
#              ('receive', 'emails', 'from'): 16,
#              ('emails', 'from', 'classroom'): 16,
#              ('from', 'classroom', 'you'): 16,
#              ('classroom', 'you', 'can'): 16,
#              ('you', 'can', 'unsubscribe'): 16,
#              ('can', 'unsubscribe', 'accounts'): 16,
#              ('unsubscribe', 'accounts', 'google'): 16,
#              ('subject', 'does', 'chat'): 1,
#              ('does', 'chat', 'replace'): 2,
#              ('chat', 'replace', 'software'): 2,
#              ('replace', 'software', 'engineers'): 2,
#              ('software', 'engineers', 'top'): 1,
#              ('engineers', 'top', 'stories'): 1,
#              ('top', 'stories', 'for'): 19,
#              ('stories', 'for', 'does'): 1,
#              ('for', 'does', 'chat'): 1,
#              ('software', 'engineers', 'from'): 1,
#              ('engineers', 'from', 'been'): 1,
#              ('from', 'been', 'using'): 1,
#              ('been', 'using', 'with'): 2,
#              ('using', 'with', 'right'): 1,
#              ('with', 'right', 'when'): 1,
#              ('right', 'when', 'it'): 1,
#              ('when', 'it', 'was'): 1,
#              ('it', 'was', 'announced'): 1,
#              ('was', 'announced', 'had'): 1,
#              ('announced', 'had', 'been'): 1,
#              ('had', 'been', 'using'): 1,
#              ('using', 'with', 'as'): 1,
#              ('with', 'as', 'my'): 1,
#              ('as', 'my', 'junior'): 1,
#              ('my', 'junior', 'engineer'): 1,
#              ('junior', 'engineer', 'for'): 1,
#              ('engineer', 'for', 'coding'): 1,
#              ('for', 'coding', 'personal'): 1,
#              ('coding', 'personal', 'projects'): 1,
#              ('personal', 'projects', 'for'): 1,
#              ('projects', 'for', 'the'): 1,
#              ('for', 'the', 'past'): 1,
#              ('the', 'past', 'few'): 1,
#              ('past', 'few', 'we'): 1,
#              ('few', 'we', 'more'): 1,
#              ('we', 'more', 'com'): 4,
#              ('more', 'com', 'al'): 228,
#              ('com', 'al', 'imp'): 228,
#              ('al', 'imp', 'al'): 228,
#              ('imp', 'al', 'cp'): 228,
#              ('al', 'cp', 'id'): 228,
#              ('cp', 'id', 'what'): 42,
#              ('id', 'what', 'is'): 20,
#              ('what', 'is', 'the'): 23,
#              ('is', 'the', 'breakup'): 1,
#              ('the', 'breakup', 'of'): 1,
#              ('breakup', 'of', 'offered'): 1,
#              ('of', 'offered', 'by'): 1,
#              ('offered', 'by', 'how'): 1,
#              ('by', 'how', 'much'): 1,
#              ('how', 'much', 'is'): 2,
#              ('much', 'is', 'the'): 2,
#              ('is', 'the', 'actual'): 1,
#              ('the', 'actual', 'base'): 1,
#              ('actual', 'base', 'salary'): 1,
#              ('base', 'salary', 'it'): 1,
#              ('salary', 'it', 'includes'): 1,
#              ('it', 'includes', 'from'): 1,
#              ('includes', 'from', 'have'): 1,
#              ('from', 'have', 'friend'): 1,
#              ('have', 'friend', 'whose'): 1,
#              ('friend', 'whose', 'brother'): 1,
#              ('whose', 'brother', 'got'): 1,
#              ('brother', 'got', 'offer'): 1,
#              ('got', 'offer', 'from'): 1,
#              ('offer', 'from', 'in'): 1,
#              ('from', 'in', 'and'): 1,
#              ('in', 'and', 'had'): 1,
#              ('and', 'had', 'bagged'): 1,
#              ('had', 'bagged', 'package'): 1,
#              ('bagged', 'package', 'of'): 1,
#              ('package', 'of', 'had'): 1,
#              ('of', 'had', 'chance'): 1,
#              ('had', 'chance', 'to'): 1,
#              ('chance', 'to', 'look'): 1,
#              ('to', 'look', 'into'): 1,
#              ('look', 'into', 'the'): 1,
#              ('into', 'the', 'breakdown'): 1,
#              ('the', 'breakdown', 'and'): 1,
#              ('breakdown', 'and', 'below'): 1,
#              ('and', 'below', 'is'): 1,
#              ('below', 'is', 'the'): 1,
#              ('is', 'the', 'more'): 1,
#              ('the', 'more', 'com'): 7,
#              ('cp', 'id', 'my'): 9,
#              ('id', 'my', 'supervisor'): 1,
#              ('my', 'supervisor', 'is'): 1,
#              ('supervisor', 'is', 'incapable'): 1,
#              ('is', 'incapable', 'of'): 1,
#              ('incapable', 'of', 'guiding'): 1,
#              ('of', 'guiding', 'me'): 1,
#              ('guiding', 'me', 'am'): 1,
#              ('me', 'am', 'his'): 1,
#              ('am', 'his', 'first'): 1,
#              ('his', 'first', 'student'): 1,
#              ('first', 'student', 'what'): 1,
#              ('student', 'what', 'should'): 1,
#              ('what', 'should', 'do'): 9,
#              ('should', 'do', 'from'): 8,
#              ('do', 'from', 'was'): 2,
#              ('from', 'was', 'my'): 1,
#              ('was', 'my', 'supervisor'): 1,
#              ('my', 'supervisor', 'first'): 1,
#              ('supervisor', 'first', 'student'): 1,
#              ('first', 'student', 'and'): 1,
#              ('student', 'and', 'do'): 1,
#              ('and', 'do', 'you'): 1,
#              ('do', 'you', 'know'): 4,
#              ('you', 'know', 'what'): 1,
#              ('know', 'what', 'he'): 1,
#              ('what', 'he', 'told'): 1,
#              ('he', 'told', 'me'): 1,
#              ('told', 'me', 'on'): 1,
#              ('me', 'on', 'my'): 1,
#              ('on', 'my', 'first'): 1,
#              ('my', 'first', 'day'): 1,
#              ('first', 'day', 'my'): 1,
#              ('day', 'my', 'official'): 1,
#              ('my', 'official', 'name'): 1,
#              ('official', 'name', 'this'): 1,
#              ('name', 'this', 'is'): 1,
#              ('this', 'is', 'going'): 1,
#              ('is', 'going', 'to'): 1,
#              ('going', 'to', 'be'): 1,
#              ('to', 'be', 'your'): 1,
#              ('be', 'your', 'you'): 1,
#              ('your', 'you', 'need'): 1,
#              ('you', 'need', 'to'): 4,
#              ('need', 'to', 'become'): 1,
#              ('to', 'become', 'the'): 1,
#              ('become', 'the', 'more'): 1,
#              ('cp', 'id', 'why'): 18,
#              ('id', 'why', 'did'): 1,
#              ('why', 'did', 'the'): 1,
#              ('did', 'the', 'resign'): 1,
#              ('the', 'resign', 'is'): 1,
#              ('resign', 'is', 'there'): 1,
#              ('is', 'there', 'any'): 3,
#              ('there', 'any', 'fraud'): 1,
#              ('any', 'fraud', 'in'): 1,
#              ('fraud', 'in', 'from'): 1,
#              ('in', 'from', 'billion'): 1,
#              ('from', 'billion', 'it'): 1,
#              ('billion', 'it', 'services'): 1,
#              ('it', 'services', 'behemoth'): 1,
#              ('services', 'behemoth', 'managing'): 1,
#              ('behemoth', 'managing', 'director'): 1,
#              ('managing', 'director', 'chief'): 1,
#              ('director', 'chief', 'executive'): 1,
#              ('chief', 'executive', 'officer'): 1,
#              ('executive', 'officer', 'announced'): 1,
#              ('officer', 'announced', 'his'): 1,
#              ('announced', 'his', 'resignation'): 1,
#              ('his', 'resignation', 'on'): 1,
#              ('resignation', 'on', 'with'): 1,
#              ('on', 'with', 'four'): 1,
#              ('with', 'four', 'years'): 1,
#              ('four', 'years', 'still'): 1,
#              ('years', 'still', 'more'): 1,
#              ('still', 'more', 'com'): 1,
#              ('cp', 'id', 'are'): 3,
#              ('id', 'are', 'you'): 3,
#              ('are', 'you', 'selected'): 2,
#              ('you', 'selected', 'in'): 2,
#              ('selected', 'in', 'the'): 2,
#              ('in', 'the', 'from'): 2,
#              ('the', 'from', 'yes'): 2,
#              ('from', 'yes', 'yes'): 2,
#              ('yes', 'yes', 'finally'): 2,
#              ('yes', 'finally', 'this'): 2,
#              ('finally', 'this', 'moment'): 2,
#              ('this', 'moment', 'came'): 2,
#              ('moment', 'came', 'in'): 2,
#              ('came', 'in', 'my'): 2,
#              ('in', 'my', 'life'): 2,
#              ('my', 'life', 'waited'): 2,
#              ('life', 'waited', 'long'): 2,
#              ('waited', 'long', 'to'): 2,
#              ('long', 'to', 'write'): 2,
#              ('to', 'write', 'this'): 2,
#              ('write', 'this', 'answer'): 2,
#              ('this', 'answer', 'but'): 2,
#              ('answer', 'but', 'never'): 2,
#              ('but', 'never', 'mind'): 2,
#              ('never', 'mind', 'better'): 2,
#              ('mind', 'better', 'late'): 2,
#              ('better', 'late', 'than'): 2,
#              ('late', 'than', 'never'): 2,
#              ('than', 'never', 'failing'): 2,
#              ('never', 'failing', 'miserably'): 2,
#              ('failing', 'miserably', 'in'): 2,
#              ('miserably', 'in', 'more'): 2,
#              ('in', 'more', 'com'): 4,
#              ('cp', 'id', 'which'): 7,
#              ('id', 'which', 'city'): 1,
#              ('which', 'city', 'of'): 1,
#              ('city', 'of', 'do'): 1,
#              ('of', 'do', 'you'): 1,
#              ('do', 'you', 'dislike'): 1,
#              ('you', 'dislike', 'the'): 1,
#              ('dislike', 'the', 'most'): 1,
#              ('the', 'most', 'in'): 1,
#              ('most', 'in', 'space'): 1,
#              ('in', 'space', 'answer'): 2,
#              ('space', 'answer', 'from'): 2,
#              ('answer', 'from', 'it'): 1,
#              ('from', 'it', 'is'): 2,
#              ('it', 'is', 'modern'): 1,
#              ('is', 'modern', 'city'): 1,
#              ('modern', 'city', 'modern'): 1,
#              ('city', 'modern', 'people'): 1,
#              ('modern', 'people', 'live'): 1,
#              ('people', 'live', 'here'): 1,
#              ('live', 'here', 'they'): 1,
#              ('here', 'they', 'don'): 1,
#              ('they', 'don', 'know'): 1,
#              ('don', 'know', 'how'): 1,
#              ('know', 'how', 'to'): 2,
#              ('how', 'to', 'respect'): 1,
#              ('to', 'respect', 'common'): 1,
#              ('respect', 'common', 'man'): 1,
#              ('common', 'man', 'incident'): 1,
#              ('man', 'incident', 'one'): 1,
#              ('incident', 'one', 'assaulted'): 1,
#              ('one', 'assaulted', 'the'): 1,
#              ('assaulted', 'the', 'security'): 1,
#              ('the', 'security', 'more'): 1,
#              ('security', 'more', 'com'): 1,
#              ('id', 'which', 'juice'): 1,
#              ('which', 'juice', 'is'): 1,
#              ('juice', 'is', 'the'): 1,
#              ('is', 'the', 'best'): 3,
#              ('the', 'best', 'for'): 1,
#              ('best', 'for', 'skin'): 1,
#              ('for', 'skin', 'whitening'): 1,
#              ('skin', 'whitening', 'from'): 1,
#              ('whitening', 'from', 'problems'): 1,
#              ('from', 'problems', 'are'): 1,
#              ('problems', 'are', 'related'): 1,
#              ('are', 'related', 'to'): 1,
#              ('related', 'to', 'unhealthy'): 1,
#              ('to', 'unhealthy', 'stomach'): 1,
#              ('unhealthy', 'stomach', 'so'): 1,
#              ('stomach', 'so', 'if'): 1,
#              ('so', 'if', 'your'): 1,
#              ('if', 'your', 'stomach'): 1,
#              ('your', 'stomach', 'is'): 1,
#              ('stomach', 'is', 'healthy'): 1,
#              ('is', 'healthy', 'your'): 1,
#              ('healthy', 'your', 'skin'): 1,
#              ('your', 'skin', 'will'): 1,
#              ('skin', 'will', 'definitely'): 1,
#              ('will', 'definitely', 'be'): 1,
#              ('definitely', 'be', 'glowing'): 1,
#              ('be', 'glowing', 'and'): 1,
#              ('glowing', 'and', 'healthy'): 1,
#              ('and', 'healthy', 'personally'): 1,
#              ('healthy', 'personally', 'believe'): 1,
#              ('personally', 'believe', 'that'): 1,
#              ('believe', 'that', 'people'): 1,
#              ('that', 'people', 'sh'): 1,
#              ('people', 'sh', 'more'): 1,
#              ('sh', 'more', 'com'): 2,
#              ('cp', 'id', 'is'): 28,
#              ('id', 'is', 'placement'): 4,
#              ('is', 'placement', 'at'): 4,
#              ('placement', 'at', 'tough'): 4,
#              ('at', 'tough', 'from'): 4,
#              ('tough', 'from', 'on'): 4,
#              ('from', 'on', 'your'): 4,
#              ('on', 'your', 'preparation'): 4,
#              ('your', 'preparation', 'am'): 4,
#              ('preparation', 'am', 'from'): 4,
#              ('am', 'from', 'circuit'): 4,
#              ('from', 'circuit', 'branch'): 4,
#              ('circuit', 'branch', 'and'): 4,
#              ('branch', 'and', 'got'): 4,
#              ('and', 'got', 'super'): 4,
#              ('got', 'super', 'dream'): 4,
#              ('super', 'dream', 'placement'): 8,
#              ('dream', 'placement', 'almost'): 4,
#              ('placement', 'almost', 'all'): 4,
#              ('almost', 'all', 'of'): 4,
#              ('all', 'of', 'my'): 4,
#              ('of', 'my', 'friends'): 4,
#              ('my', 'friends', 'have'): 4,
#              ('friends', 'have', 'also'): 4,
#              ('have', 'also', 'got'): 4,
#              ('also', 'got', 'dream'): 4,
#              ('got', 'dream', 'super'): 4,
#              ('dream', 'super', 'dream'): 4,
#              ('dream', 'placement', 'my'): 4,
#              ('placement', 'my', 'op'): 4,
#              ('my', 'op', 'more'): 4,
#              ('op', 'more', 'com'): 4,
#              ('cp', 'id', 'how'): 20,
#              ('id', 'how', 'lottery'): 1,
#              ('how', 'lottery', 'winners'): 1,
#              ('lottery', 'winners', 'are'): 2,
#              ('winners', 'are', 'selected'): 2,
#              ('are', 'selected', 'from'): 1,
#              ('selected', 'from', 'lottery'): 1,
#              ('from', 'lottery', 'winners'): 1,
#              ('are', 'selected', 'by'): 1,
#              ('selected', 'by', 'computer'): 1,
#              ('by', 'computer', 'system'): 1,
#              ('computer', 'system', 'that'): 1,
#              ('system', 'that', 'chooses'): 1,
#              ('that', 'chooses', 'applications'): 1,
#              ('chooses', 'applications', 'totally'): 1,
#              ('applications', 'totally', 'at'): 1,
#              ('totally', 'at', 'random'): 1,
#              ('at', 'random', 'within'): 1,
#              ('random', 'within', 'the'): 1,
#              ('within', 'the', 'parameters'): 1,
#              ('the', 'parameters', 'required'): 1,
#              ('parameters', 'required', 'by'): 1,
#              ('required', 'by', 'the'): 1,
#              ('by', 'the', 'system'): 1,
#              ('the', 'system', 'numbers'): 1,
#              ('system', 'numbers', 'from'): 1,
#              ('numbers', 'from', 'certain'): 1,
#              ('from', 'certain', 'areas'): 1,
#              ('certain', 'areas', 'more'): 1,
#              ('areas', 'more', 'com'): 1,
#              ('id', 'is', 'it'): 6,
#              ('is', 'it', 'okay'): 4,
#              ('it', 'okay', 'to'): 2,
#              ('okay', 'to', 'let'): 1,
#              ('to', 'let', 'my'): 1,
#              ('let', 'my', 'year'): 2,
#              ('my', 'year', 'old'): 6,
#              ('year', 'old', 'son'): 3,
#              ('old', 'son', 'sleep'): 1,
#              ('son', 'sleep', 'in'): 1,
#              ('sleep', 'in', 'the'): 1,
#              ('in', 'the', 'same'): 3,
#              ('the', 'same', 'room'): 1,
#              ('same', 'room', 'as'): 1,
#              ('room', 'as', 'her'): 1,
#              ('as', 'her', 'year'): 1,
#              ('her', 'year', 'old'): 1,
#              ('year', 'old', 'sister'): 2,
#              ('old', 'sister', 'from'): 1,
#              ('sister', 'from', 'was'): 1,
#              ('from', 'was', 'found'): 1,
#              ('was', 'found', 'my'): 1,
#              ('found', 'my', 'year'): 1,
#              ('year', 'old', 'brother'): 1,
#              ('old', 'brother', 'far'): 1,
#              ('brother', 'far', 'to'): 1,
#              ('far', 'to', 'annoying'): 1,
#              ('to', 'annoying', 'and'): 1,
#              ('annoying', 'and', 'had'): 1,
#              ('and', 'had', 'all'): 1,
#              ('had', 'all', 'those'): 1,
#              ('all', 'those', 'teenage'): 1,
#              ('those', 'teenage', 'hormones'): 1,
#              ('teenage', 'hormones', 'bouncing'): 1,
#              ('hormones', 'bouncing', 'around'): 1,
#              ('bouncing', 'around', 'especially'): 1,
#              ('around', 'especially', 'want'): 1,
#              ('especially', 'want', 'anyone'): 1,
#              ('want', 'anyone', 'in'): 1,
#              ('anyone', 'in', 'my'): 1,
#              ('in', 'my', 'room'): 1,
#              ('my', 'room', 'at'): 1,
#              ('room', 'at', 'that'): 1,
#              ('at', 'that', 'stage'): 1,
#              ('that', 'stage', 'more'): 1,
#              ('stage', 'more', 'com'): 1,
#              ('is', 'the', 'reason'): 2,
#              ('the', 'reason', 'is'): 1,
#              ('reason', 'is', 'not'): 1,
#              ('is', 'not', 'as'): 1,
#              ('not', 'as', 'popular'): 1,
#              ('as', 'popular', 'as'): 1,
#              ('popular', 'as', 'python'): 1,
#              ('as', 'python', 'for'): 1,
#              ('python', 'for', 'data'): 1,
#              ('for', 'data', 'science'): 1,
#              ('data', 'science', 'from'): 1,
#              ('science', 'from', 'was'): 1,
#              ('from', 'was', 'released'): 1,
#              ('was', 'released', 'five'): 1,
#              ('released', 'five', 'years'): 1,
#              ('five', 'years', 'ago'): 1,
#              ('years', 'ago', 'in'): 2,
#              ('ago', 'in', 'python'): 1,
#              ('in', 'python', 'was'): 1,
#              ('python', 'was', 'released'): 1,
#              ('was', 'released', 'twenty'): 1,
#              ('released', 'twenty', 'nine'): 1,
#              ('twenty', 'nine', 'years'): 1,
#              ('nine', 'years', 'ago'): 1,
#              ('ago', 'in', 'and'): 1,
#              ('in', 'and', 'was'): 1,
#              ('and', 'was', 'already'): 1,
#              ('was', 'already', 'one'): 1,
#              ('already', 'one', 'of'): 1,
#              ('one', 'of', 'the'): 9,
#              ('of', 'the', 'most'): 2,
#              ('the', 'most', 'popular'): 2,
#              ('most', 'popular', 'languages'): 1,
#              ('popular', 'languages', 'in'): 1,
#              ('languages', 'in', 'any'): 1,
#              ('in', 'any', 'domain'): 1,
#              ...})

# %%
df = pd.DataFrame(list(word_sequences.items()), columns=['Word Sequence', 'Frequency'])
df[['Word1', 'Word2', 'Word3']] = pd.DataFrame(df['Word Sequence'].to_list(), index=df.index)
df.drop(columns=['Word Sequence'], inplace=True)
multi_index = pd.MultiIndex.from_frame(df[['Word1', 'Word2']])
trigram = df.set_index(multi_index).pivot(columns='Word3', values='Frequency').fillna(0)

# %%
def get_next_word_bigram(word: str):
    next_possible_words = bigram[bigram[word] > 0].index.tolist()
    if not next_possible_words: return None
    freqs = bigram.loc[next_possible_words, word].tolist() 
    weights = np.array(freqs) / sum(freqs)
    return np.random.choice(next_possible_words, p=weights)

# %%
def random_text_generator(text_length: int) -> str:
    random_num = np.random.randint(0, number_of_unique_words)
    random_text = [list(words)[random_num]]
    curr_word = random_text[0]  
    text_length -= 1 
    while text_length:
        curr_word = get_next_word_bigram(curr_word)
        if curr_word is None: break
        random_text.append(curr_word)
        text_length -= 1
    
    return ' '.join(random_text)

# %%
def random_text_generator_trigram(text_length: int) -> str:
    # get the first word randomly from the list of words
    # for the second use the bigram
    # from then onwards use trigram for the third word
    random_num = np.random.randint(0, number_of_unique_words)
    random_text = [list(words)[random_num]]
    curr_word1 = random_text[0]
    if text_length == 1: return curr_word1
    curr_word2 = get_next_word_bigram(curr_word1)
    random_text.append(curr_word2)
    text_length -= 2
    while text_length:
        if (curr_word1, curr_word2) not in trigram.index:
            return ' '.join(random_text)
        df = trigram.loc[(curr_word1, curr_word2),:]
        next_possible_words = df[df > 0].dropna().index.tolist()
        if not next_possible_words: break
        freqs = df[df>0].dropna().values.tolist()
        weights = np.array(freqs) / sum(freqs)
        next_word = np.random.choice(next_possible_words, p=weights)
        random_text.append(next_word)
        curr_word1 = curr_word2
        curr_word2 = next_word
        text_length -= 1
        
    return ' '.join(random_text)

# %%
random_text_generator(10)
# Out:
# 'compiled java has got meeting invite with more com email'

# %%
random_text_generator_trigram(10)
# Out:
# 'flags fly high we celebrate pride month you are not'
